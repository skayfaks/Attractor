# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Internal
from backend.connection.connector import Database
# External
import plotly.graph_objects as go

# %%
db = Database()

# %%
    fig.show()
    return data

test = plot_histogram()
# Out:
# <div>
#
#
#             <div id="a040718e-c4d7-465b-a201-29fd58a7c754" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a040718e-c4d7-465b-a201-29fd58a7c754")) {
#                     Plotly.newPlot(
#                         'a040718e-c4d7-465b-a201-29fd58a7c754',
# ...
