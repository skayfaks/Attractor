# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import datetime

# %%
df = pd.DataFrame({
   'id':[],
   'name':[],
   'url':[],
})

# %%
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 YaBrowser/23.11.0.0 Safari/537.36'
      }

# %%
def zakup_df (soup, data = df): 
    list_ = soup.find_all('div', {'class': 'col-8 pr-0'})
    for i in list_:
        quote = {}     
        temp = i.find('div', attrs = {'registry-entry__header-mid__number'}).find('a').text
        quote['id'] = re.findall("\d+", temp)[0]
        try:
               quote['name'] = i.find('div', attrs = {'registry-entry__body-value'}).text 
        except Exception:
            quote['name'] = 'Нет названия'
        quote['url'] = 'https://zakupki.gov.ru/' + i.find('div', attrs = {'registry-entry__header-mid__number'}).find('a').get('href')
        df.loc[len(df)] = quote

# %%
for i in range(1, 960): #На сайте 50 страниц (1000 книг по 20 на странице)
    url = 'https://zakupki.gov.ru/epz/order/extendedsearch/results.html?morphology=on&search-filter=Дате+размещения&pageNumber=' + str(i) + '&sortDirection=false&recordsPerPage=_50&showLotsInfoHidden=false&sortBy=UPDATE_DATE&fz44=on&fz223=on&af=on&ca=on&pc=on&pa=on&currencyIdGeneral=-1&publishDateFrom=01.01.2023&publishDateTo=27.01.2024&okpd2IdsWithNested=on&okpd2Ids=8873937%2C8873938&okpd2IdsCodes=62%2C63'
    r = requests.get(url, headers = headers, timeout = 10)
    soup = BeautifulSoup(r.content, 'html.parser')    
    zakup_df(soup, df)

# %% [markdown]
# 18 минут 20 сек парсилось

# %%
import datetime
current_time = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"file_{current_time}.csv"
df.to_csv(filename)

# %%
data = pd.read_csv('./file_2024-01-28_22-24-03.csv', encoding='utf-8')
data.drop(['Unnamed: 0'], axis = 1, inplace = True)
data.head(4)
# Out:
#                    id                                               name  \
# 0  122200001024000004  Оказание информационных услуг с использованием...
# 1  822200000224000005   Поставка электронного периодического справочника
# 2         32413220504  Оказание услуг по технической и контентной под...
#
#                                                  url
# 0  https://zakupki.gov.ru//epz/order/notice/zk20/...
# 1  https://zakupki.gov.ru//epz/order/notice/zk20/...
# 2  https://zakupki.gov.ru//epz/order/notice/notic...

# %%
data2 = pd.read_csv('D:/1.Projects/1t/attractor/df_soup/df.csv', encoding='cp1251')
# data.drop(['Unnamed: 0'], axis = 1, inplace = True)
data2.head(4)
# Out:
#   Закупки по Реестровый номер закупки  \
# 0     223-ФЗ             №32413225377
# 1     223-ФЗ             №32413225549
# 2     223-ФЗ             №32413201591
# 3      44-ФЗ     №0360200020124000008
#
#   Способ определения поставщика (подрядчика, исполнителя), подрядной организации (размещения закупки)  \
# 0                                             Прочие
# 1  Запрос котировок в электронной форме, участник...
# 2  Конкурс в электронной форме, участниками котор...
# 3                                Электронный аукцион
#
#                                 Наименование закупки  \
# 0  Оказание услуг по сопровождению и техническому...
# 1  Оказание услуг по внедрению и сопровождению си...
# 2  Конкурс в электронной форме участниками которо...
# 3  Оказание услуги по технической поддержке элект...
#
#    Предмет электронного аукциона (только для ПП РФ 615)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#             Идентификационный код закупки  Номер лота  \
# 0                                     NaN         1.0
# 1                                     NaN         1.0
# 2                                     NaN         1.0
# 3  '242644901690664490100100170016202244'         NaN
#
#                                    Наименование лота  \
# 0  Оказание услуг по сопровождению и техническому...
# 1  Оказание услуг по внедрению и сопровождению си...
# 2  Выполнение работ по внедрению информационной с...
# 3                                                NaN
#
#    Начальная (максимальная) цена контракта Валюта  ...  \
# 0                                2736000.0    RUB  ...
# 1                                 220000.0    RUB  ...
# 2                               25784024.4    RUB  ...
# 3                                  65520.0    RUB  ...
#
#                                          Код позиции  \
# 0  62.03.12.130: Услуги по сопровождению компьюте...
# 1  63.12.10.000: Содержание порталов в информацио...
# 2  62.01.11.000: Услуги по проектированию и разра...
# 3  62.02.30.000: Услуги по технической поддержке ...
#
#                               Наименование Заказчика  \
# 0  МУНИЦИПАЛЬНОЕ ВОДОКАНАЛИЗАЦИОННОЕ ПРЕДПРИЯТИЕ ...
# 1  АВТОНОМНОЕ УЧРЕЖДЕНИЕ "МЕДИА-ЦЕНТР ОРЕХОВО-ЗУЕ...
# 2                АКЦИОНЕРНОЕ ОБЩЕСТВО "МОСВОДОКАНАЛ"
# 3  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ  САРАТОВС...
#
#              Организация, осуществляющая размещение   Дата размещения  \
# 0                                                NaN       29.01.2024
# 1                                                NaN       29.01.2024
# 2                                                NaN       22.01.2024
# 3  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ УЧРЕЖДЕНИЕ  САРАТОВС...       29.01.2024
#
#   Дата обновления     Этап закупки  \
# 0      29.01.2024  Работа комиссии
# 1      29.01.2024    Подача заявок
# 2      29.01.2024    Подача заявок
# 3      29.01.2024    Подача заявок
#
#   Особенности размещения заказа\ Преимущества (44-ФЗ)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Преимущество в соответствии с ч. 3 ст. 30 Зако...
#
#   Дата начала подачи заявок Дата окончания подачи заявок  \
# 0                29.01.2024                   29.01.2024
# 1                29.01.2024                   06.02.2024
# 2                22.01.2024                   05.02.2024
# 3                29.01.2024                   07.02.2024
#
#   Дата проведения электронного аукциона
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
#
# [4 rows x 25 columns]

# %%
data2.shape
# Out:
# (2813, 25)

# %% [markdown]
# новый  ДАТАСЕТ

# %%
data = pd.read_csv('D:/1.Projects/1t/attractor/ds/file_2.csv', encoding='utf-8')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              50 non-null     uint64
#  1   name            50 non-null     object
#  2   url             50 non-null     object
#  3   fz              50 non-null     int64
#  4   type_of_tender  50 non-null     object
#  5   status          50 non-null     object
#  6   price           50 non-null     object
# dtypes: int64(1), object(5), uint64(1)
# memory usage: 2.9+ KB

# %%
data['price'] = data['price'].str.replace(' ', '').str.replace('\xa0', '').str.replace('₽', '').str.replace(',', '.').astype(float)

# %%
data
# Out:
#                      id                                               name  \
# 19               Запрос котировок в электронной форме
# 20               Запрос котировок в электронной форме
# 21                                Электронный аукцион
# 22                                Электронный аукцион
# 23                                Электронный аукцион
# 24               Запрос котировок в электронной форме
# 25               Запрос котировок в электронной форме
# 26                                Электронный аукцион
# 27                                Электронный аукцион
# 28  Запрос предложений в электронной форме, участн...
# 29                                Электронный аукцион
# 30                                Электронный аукцион
# 31               Запрос котировок в электронной форме
# 32               Запрос котировок в электронной форме
# 33               Открытый конкурс в электронной форме
# 34                                Электронный аукцион
# 35               Запрос котировок в электронной форме
# 36                                Электронный аукцион
# 37                                Электронный аукцион
# 38                                Электронный аукцион
# 39               Открытый конкурс в электронной форме
# 40                                Электронный аукцион
# 41               Запрос котировок в электронной форме
# 42                                             Прочие
# 43  Конкурс в электронной форме, участниками котор...
# 44               Запрос котировок в электронной форме
# 45                                Электронный аукцион
# 46               Запрос котировок в электронной форме
# 47                                Электронный аукцион
# 48                                Электронный аукцион
# 49                                Электронный аукцион
#
#                               status        price
# 0                    Работа комиссии   2736000.00
# 1                      Подача заявок    220000.00
# 2                  Закупка завершена    249124.85
# 3                      Подача заявок  25784024.40
# 4                  Закупка завершена    277942.08
# 5                      Подача заявок     65520.00
# 6                    Работа комиссии    107369.16
# 7   Определение поставщика завершено     10000.00
# 8   Определение поставщика завершено    168192.00
# 9   Определение поставщика завершено  10235000.00
# 10  Определение поставщика завершено     48270.00
# 11                     Подача заявок   9500000.00
# 12  Определение поставщика завершено    157400.00
# 13                     Подача заявок    500400.00
# 14                   Работа комиссии    235720.98
# 15                     Подача заявок    798480.00
# 16                     Подача заявок   5061568.83
# 17                     Подача заявок   7370000.00
# 18                     Подача заявок    951279.96
# 19                   Работа комиссии    346720.99
# 20  Определение поставщика завершено    355351.92
# 21                     Подача заявок   2793736.00
# 22                     Подача заявок   2080900.00
# 23                     Подача заявок    166243.00
# 24                     Подача заявок    249000.00
# 25                     Подача заявок     71823.33
# 26                     Подача заявок    278135.00
# 27                     Подача заявок    578748.00
# 28                     Подача заявок    397800.00
# 29                   Работа комиссии    172423.33
# 30                     Подача заявок    297000.00
# 31  Определение поставщика завершено    546700.00
# 32                     Подача заявок    543840.00
# 33                     Подача заявок  56294557.91
# 34                     Подача заявок   8520000.00
# 35  Определение поставщика завершено     48270.00
# 36                     Подача заявок    167562.00
# 37                     Подача заявок    189260.10
# 38  Определение поставщика завершено    714899.16
# 39                     Подача заявок  59743226.85
# 40                     Подача заявок     33500.00
# 41  Определение поставщика завершено    985820.00
# 42                 Закупка завершена   4100000.00
# 43                     Подача заявок   1338000.00
# 44                     Подача заявок    390500.00
# 45                     Подача заявок    271010.00
# 46                     Подача заявок   2398598.40
# 47                     Подача заявок    752184.00
# 48                     Подача заявок    749970.00
# 49                     Подача заявок  10449000.00
